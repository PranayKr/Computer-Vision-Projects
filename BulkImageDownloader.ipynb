# %%
from bs4 import BeautifulSoup
import requests
import re
#import urllib2
import urllib.request
import os
#import cookielib
import http.cookiejar as cookielib
import json

# %%
def get_soup(url,header):
    #return BeautifulSoup(urllib2.urlopen(urllib2.Request(url,headers=header)),'html.parser')
    return BeautifulSoup(urllib.request.urlopen(urllib.request.Request(url,headers=header)),'html.parser')


#query = raw_input("Cat")# you can change the query for the image  here
query = "Cat"
image_type="ActiOn"
query= query.split()
query='+'.join(query)
url="https://www.google.co.in/search?q="+query+"&source=lnms&tbm=isch"
print(url)
#add the directory for your image here
DIR="Pictures"
header={'User-Agent':"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/43.0.2357.134 Safari/537.36"
}
soup = get_soup(url,header)


ActualImages=[]# contains the link for Large original images, type of  image
for a in soup.find_all("div",{"class":"rg_meta"}):
    link , Type =json.loads(a.text)["ou"]  ,json.loads(a.text)["ity"]
    ActualImages.append((link,Type))

print("there are total" , len(ActualImages),"images")

if not os.path.exists(DIR):
            os.mkdir(DIR)
DIR = os.path.join(DIR, query.split()[0])

if not os.path.exists(DIR):
            os.mkdir(DIR)
###print images
for i , (img , Type) in enumerate( ActualImages):
    try:
        #req = urllib2.Request(img, headers={'User-Agent' : header})
        #req = urllib.request.Request(img, headers={'User-Agent' : header})        
        req = urllib.request.Request(img)     
        #print(req)
        #raw_img = urllib2.urlopen(req).read()
        raw_img = urllib.request.urlopen(req).read()      
        cntr = len([i for i in os.listdir(DIR) if image_type in i]) + 1
        #print("hells")
        print(cntr)
        if len(Type)==0:
            f = open(os.path.join(DIR , image_type + "_"+ str(cntr)+".jpg"), 'wb')
        else :
            f = open(os.path.join(DIR , image_type + "_"+ str(cntr)+"."+Type), 'wb')

        f.write(raw_img)
        f.close()
    except Exception as e:
        print("could not load : "+img)
        print(e)
# Out:
# https://www.google.co.in/search?q=Cat&source=lnms&tbm=isch
# there are total 100 images
# <urllib.request.Request object at 0x000001E1E4C38E80>
# could not load : https://images.pexels.com/photos/617278/pexels-photo-617278.jpeg?auto=compress&cs=tinysrgb&h=350
# HTTP Error 403: Forbidden
# <urllib.request.Request object at 0x000001E1E511DAC8>
# cgecaswka
# 1
# <urllib.request.Request object at 0x000001E1E67AF9E8>
# cgecaswka
# 2
# <urllib.request.Request object at 0x000001E1E4C38E80>
# cgecaswka
# 3
# <urllib.request.Request object at 0x000001E1E6432588>
# cgecaswka
# 4
# <urllib.request.Request object at 0x000001E1E4D72FD0>
# cgecaswka
# 5
# <urllib.request.Request object at 0x000001E1E501EEB8>
# could not load : https://www.readersdigest.ca/wp-content/uploads/2011/01/4-ways-cheer-up-depressed-cat.jpg
# HTTP Error 403: Forbidden
# <urllib.request.Request object at 0x000001E1E66B0CC0>
# could not load : https://images.pexels.com/photos/104827/cat-pet-animal-domestic-104827.jpeg?cs=srgb&dl=animal-animal-photography-cat-104827.jpg&fm=jpg
# HTTP Error 403: Forbidden
# <urllib.request.Request object at 0x000001E1E4C38E80>
# cgecaswka
# 6
# <urllib.request.Request object at 0x000001E1E501EE10>
# cgecaswka
# 7
# <urllib.request.Request object at 0x000001E1E66B0CC0>
# could not load : https://www.pets4homes.co.uk/images/articles/771/large/cat-lifespan-the-life-expectancy-of-cats-568e40723c336.jpg
# HTTP Error 403: Forbidden
# <urllib.request.Request object at 0x000001E1E436D0F0>
# cgecaswka
# 8
# <urllib.request.Request object at 0x000001E1E4D72FD0>
# cgecaswka
# 9
# <urllib.request.Request object at 0x000001E1E4ED8320>
# cgecaswka
# 10
# <urllib.request.Request object at 0x000001E1E4D72FD0>
# cgecaswka
# 11
# <urllib.request.Request object at 0x000001E1E501EE80>
# cgecaswka
# 12
# <urllib.request.Request object at 0x000001E1E511DAC8>
# could not load : https://www.bluecross.org.uk/sites/default/files/assets/images/124044lpr.jpg
# HTTP Error 403: Forbidden
# <urllib.request.Request object at 0x000001E1E67AF358>
# cgecaswka
# 13
# <urllib.request.Request object at 0x000001E1E61F60F0>
# cgecaswka
# 14
# <urllib.request.Request object at 0x000001E1E511DAC8>
# could not load : https://images.pexels.com/photos/259803/pexels-photo-259803.jpeg?cs=srgb&dl=animal-pet-cute-259803.jpg&fm=jpg
# HTTP Error 403: Forbidden
# <urllib.request.Request object at 0x000001E1E436D0F0>
# could not load : https://www.rd.com/wp-content/uploads/2016/04/01-cat-wants-to-tell-you-laptop.jpg
# HTTP Error 403: Forbidden
# <urllib.request.Request object at 0x000001E1E67AF9E8>
# cgecaswka
# 15
# <urllib.request.Request object at 0x000001E1E67AF358>
# cgecaswka
# 16
# <urllib.request.Request object at 0x000001E1E501EEB8>
# cgecaswka
# 17
# <urllib.request.Request object at 0x000001E1E61F6048>
# cgecaswka
# 18
# <urllib.request.Request object at 0x000001E1E436D0F0>
# could not load : https://catscornervet.com/wp-content/uploads/2016/04/kitty-1.png
# HTTP Error 403: Forbidden
# <urllib.request.Request object at 0x000001E1E501EE10>
# cgecaswka
# 19
# <urllib.request.Request object at 0x000001E1E4D72FD0>
# cgecaswka
# 20
# <urllib.request.Request object at 0x000001E1E4C38780>
# cgecaswka
# 21
# <urllib.request.Request object at 0x000001E1E4C38E80>
# cgecaswka
# 22
# <urllib.request.Request object at 0x000001E1E4D72FD0>
# cgecaswka
# 23
# <urllib.request.Request object at 0x000001E1E4ED8BA8>
# cgecaswka
# 24
# <urllib.request.Request object at 0x000001E1E501EEB8>
# could not load : https://images.pexels.com/photos/326875/pexels-photo-326875.jpeg?cs=srgb&dl=adorable-animal-blur-326875.jpg&fm=jpg
# HTTP Error 403: Forbidden
# <urllib.request.Request object at 0x000001E1E4C38E80>
# cgecaswka
# 25
# <urllib.request.Request object at 0x000001E1E67AF358>
# cgecaswka
# 26
# <urllib.request.Request object at 0x000001E1E4ED8A58>
# cgecaswka
# 27
# <urllib.request.Request object at 0x000001E1E61F6048>
# cgecaswka
# 28
# <urllib.request.Request object at 0x000001E1E67AF358>
# cgecaswka
# 29
# <urllib.request.Request object at 0x000001E1E6432588>
# cgecaswka
# 30
# <urllib.request.Request object at 0x000001E1E61F6048>
# cgecaswka
# 31
# <urllib.request.Request object at 0x000001E1E67AF358>
# cgecaswka
# 32
# <urllib.request.Request object at 0x000001E1E4C38E80>
# cgecaswka
# 33
# <urllib.request.Request object at 0x000001E1E4D72FD0>
# cgecaswka
# 34
# <urllib.request.Request object at 0x000001E1E501EE80>
# could not load : http://mymodernmet.com/wp/wp-content/uploads/2017/11/minimalist-cat-art-subreddit-10.jpg
# HTTP Error 403: Forbidden
# <urllib.request.Request object at 0x000001E1E67AF358>
# cgecaswka
# 35
# <urllib.request.Request object at 0x000001E1E436D0F0>
# could not load : https://cdn-images-1.medium.com/max/1600/1*mONNI1lG9VuiqovpnYqicA.jpeg
# HTTP Error 403: Forbidden
# <urllib.request.Request object at 0x000001E1E6432588>
# cgecaswka
# 36
# <urllib.request.Request object at 0x000001E1E64324E0>
# cgecaswka
# 37
# <urllib.request.Request object at 0x000001E1E436D0F0>
# cgecaswka
# 38
# <urllib.request.Request object at 0x000001E1E4ED8BA8>
# cgecaswka
# 39
# <urllib.request.Request object at 0x000001E1E436D0F0>
# cgecaswka
# 40
# <urllib.request.Request object at 0x000001E1E4D72FD0>
# cgecaswka
# 41
# <urllib.request.Request object at 0x000001E1E511DAC8>
# cgecaswka
# 42
# <urllib.request.Request object at 0x000001E1E64324E0>
# cgecaswka
# 43
# <urllib.request.Request object at 0x000001E1E4D72FD0>
# cgecaswka
# 44
# <urllib.request.Request object at 0x000001E1E511DAC8>
# cgecaswka
# 45
# <urllib.request.Request object at 0x000001E1E64324E0>
# could not load : https://www.rd.com/wp-content/uploads/2016/04/06-cat-wants-to-tell-you-gift.jpg
# HTTP Error 403: Forbidden
# <urllib.request.Request object at 0x000001E1E67AF358>
# cgecaswka
# 46
# <urllib.request.Request object at 0x000001E1E4D72FD0>
# could not load : https://xenlife.com.au/wp-content/uploads/ba03237a6d6499f0e2633314826e1526.jpg
# HTTP Error 403: Forbidden
# <urllib.request.Request object at 0x000001E1E61F60F0>
# cgecaswka
# 47
# <urllib.request.Request object at 0x000001E1E61F6048>
# cgecaswka
# 48
# <urllib.request.Request object at 0x000001E1E4D72FD0>
# cgecaswka
# 49
# <urllib.request.Request object at 0x000001E1E67AF358>
# cgecaswka
# 50
# <urllib.request.Request object at 0x000001E1E6432588>
# could not load : https://www.purina.co.uk/sites/g/files/mcldtz776/files/2017-11/How-old-is-my-cat-in-human-years.jpg
# HTTP Error 403: Forbidden
# <urllib.request.Request object at 0x000001E1E511DAC8>
# cgecaswka
# 51
# <urllib.request.Request object at 0x000001E1E4D72FD0>
# cgecaswka
# 52
# <urllib.request.Request object at 0x000001E1E6432588>
# cgecaswka
# 53
# <urllib.request.Request object at 0x000001E1E511DAC8>
# cgecaswka
# 54
# <urllib.request.Request object at 0x000001E1E4D72FD0>
# cgecaswka
# 55
# <urllib.request.Request object at 0x000001E1E6432588>
# could not load : https://images.pexels.com/photos/45201/kitty-cat-kitten-pet-45201.jpeg?cs=srgb&dl=animal-cat-cute-45201.jpg&fm=jpg
# HTTP Error 403: Forbidden
# <urllib.request.Request object at 0x000001E1E61F60F0>
# could not load : http://media.petsathome.com/wcsstore/pah-cas01//c/catL.png
# HTTP Error 403: Forbidden
# <urllib.request.Request object at 0x000001E1E4C38E80>
# cgecaswka
# 56
# <urllib.request.Request object at 0x000001E1E4ED8320>
# cgecaswka
# 57
# <urllib.request.Request object at 0x000001E1E4ED8128>
# cgecaswka
# 58
# <urllib.request.Request object at 0x000001E1E4C38E80>
# cgecaswka
# 59
# <urllib.request.Request object at 0x000001E1E511DAC8>
# cgecaswka
# 60
# <urllib.request.Request object at 0x000001E1E61F60F0>
# cgecaswka
# 61
# <urllib.request.Request object at 0x000001E1E4C38E80>
# could not load : https://thumbs-prod.si-cdn.com/rreY5bT-562QVxiR2LJQj5Kvz-Y=/800x600/filters:no_upscale()/https://public-media.smithsonianmag.com/filer/f5/72/f5723c57-b8c0-48a1-bf7c-aaa4c2d918fd/ax50mk.jpg
# HTTP Error 403: Forbidden
# <urllib.request.Request object at 0x000001E1E511DAC8>
# cgecaswka
# 62
# <urllib.request.Request object at 0x000001E1E67AF358>
# could not load : https://www.argospetinsurance.co.uk/assets/uploads/2017/10/pexels-photo-416160.jpeg
# HTTP Error 403: Forbidden
# <urllib.request.Request object at 0x000001E1E436D0F0>
# cgecaswka
# 63
# <urllib.request.Request object at 0x000001E1E64324E0>
# cgecaswka
# 64
# <urllib.request.Request object at 0x000001E1E67AF9E8>
# cgecaswka
# 65
# <urllib.request.Request object at 0x000001E1E436D0F0>
# cgecaswka
# 66
# <urllib.request.Request object at 0x000001E1E511DAC8>
# cgecaswka
# 67
# <urllib.request.Request object at 0x000001E1E61F60F0>
# cgecaswka
# 68
# <urllib.request.Request object at 0x000001E1E436D0F0>
# cgecaswka
# 69
# <urllib.request.Request object at 0x000001E1E61F6048>
# cgecaswka
# 70
# <urllib.request.Request object at 0x000001E1E61F60F0>
# cgecaswka
# 71
# <urllib.request.Request object at 0x000001E1E436D0F0>
# cgecaswka
# 72
# <urllib.request.Request object at 0x000001E1E4ED8320>
# cgecaswka
# 73
# <urllib.request.Request object at 0x000001E1E436D0F0>
# cgecaswka
# 74
# <urllib.request.Request object at 0x000001E1E67AF9E8>
# cgecaswka
# 75
# <urllib.request.Request object at 0x000001E1E501EEB8>
# cgecaswka
# 76
# <urllib.request.Request object at 0x000001E1E436D0F0>
# cgecaswka
# 77
# <urllib.request.Request object at 0x000001E1E67AF9E8>
# cgecaswka
# 78
# <urllib.request.Request object at 0x000001E1E501EEB8>
# cgecaswka
# 79
# <urllib.request.Request object at 0x000001E1E436D0F0>
# cgecaswka
# 80
# <urllib.request.Request object at 0x000001E1E4D72FD0>
# cgecaswka
# 81
# <urllib.request.Request object at 0x000001E1E436D0F0>
# could not load : http://pngimg.com/uploads/cat/cat_PNG50514.png
# HTTP Error 403: Forbidden
